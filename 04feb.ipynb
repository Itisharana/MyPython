# %%
import re

# %%
text = "my name is itisha 4378732980"

# %%
result = re.search(r"\d{10}", text)
print(result)
# Out:
# <re.Match object; span=(18, 28), match='4378732980'>

# %%
print(result.group())
# Out:
# 4378732980

# %%
number = result.group()

# %%
print (number)
# Out:
# 4378732980

# %%
type(result)
# Out:
# re.Match

# %%
type(number)
# Out:
# str

# %%
number = int(number)

# %%
type(number)
# Out:
# int

# %%
number
# Out:
# 4378732980

# %%
message = 'i have got 77 in english and 98 in maths'

# %%
marks = re.findall(r"\d+", message)

# %%
type(marks)
# Out:
# list

# %%
marks
# Out:
# ['77', '98']

# %%
n = len(marks)
summ = 0
for i in range(n):
    summ += int(marks[i]) 
print(summ)
# Out:
# 175

# %%
re.sub(r"\d","*", message)
# Out:
# 'i have got ** in english and ** in maths'

# %%
message
# Out:
# 'i have got 77 in english and 98 in maths'

# %%
re.split(r"\s+", message)
# Out:
# ['i', 'have', 'got', '77', 'in', 'english', 'and', '98', 'in', 'maths']

# %%
password = input("enter pass")
pattern = r"^(?=.*[A-Z])(?=.*[a-z])(?=.*\d)(?=.*[!@#$%^&*()]).{8,}$"
if re.match(pattern, password):
    print('strong pass')
else:
    print('weak pass')
# Out:
# enter pass Itisha@123
# strong pass

# %%
def bank(balance):
    
    deposite = int(input("amount to be deposited"))
    balance+=deposite
    return "total amount", balance

balance=0    
balancebank(balance)
# Out:
# amount to be deposited 30
# ('total amount', 30)

# %%
bank(balance)
# Out:
# amount to be deposited 30
# ('total amount', 30)

# %%
def bank(balance):
    deposit = int(input("Amount to be deposited: "))
    balance += deposit
    return balance
    
'''
this is another code if we use balance gloabally
balance =0
def bank():
    global balance
    deposit = int(input("Amount to be deposited: "))
    balance += deposit
    print("Current balance:", balance)'''



balance = 0   # starting once only (IMPORTANT)

while True:
    balance = bank(balance)
    print("Current balance:", balance)

    choice = input("Deposit again? (y/n): ")
    if choice.lower() != 'y':
        break
# Out:
# Amount to be deposited:  3444
# Current balance: 3444
# Deposit again? (y/n):  n

# %%
bank(balance)
# Out:
# Amount to be deposited:  2333
# 5777
