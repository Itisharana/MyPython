# %% [markdown]
# ## oops
# Helps to create design or blueprint for our progrm . It creates objects
# 4 pillars:
# 1. Encapsulation
# 2. Inheritance
# 3. Polymorphism
# 4. Abstraction

# %%
class phone:
    x=6
    y=7

# %%
obj = phone()

# %%
obj.x
# Out:
# 6

# %%
x = 44

# %%
obj.x
# Out:
# 6

# %%
type(obj.x)
# Out:
# int

# %%
print(x*obj.x)
# Out:
# 264

# %%
obj1  = phone()

# %%
obj1.x*obj.y
# Out:
# 42

# %%
obj.x*obj.y
# Out:
# 42

# %%
class calc:
    def add(self,a,b):
        print(a+b)
    def sub(self,a,b):
        print (a-b)

# %%
abc = calc()

# %%
abc.add(4,5)
# Out:
# 9

# %%
class king:
    def __init__(self, name):
        self.name = name
        print('this code is for', self.name)
        print('use below functions\n1.)add \n2.)sub \n3.)mul')
    def add(self, a, b):
        print(a+b)
    def sub(self, a, b):
        print(a-b)
    def mul(self, a, b):
        print(a*b)
    def info(self):
        print("this code belongs to ", self.name )

# %%
aa = king('rajat')
# Out:
# this code is for rajat
# use below functions
# 1.)add
# 2.)sub
# 3.)mul

# %%
aa.add(6,9)
# Out:
# 15

# %%
aa.info()
# Out:
# this code belongs to  rajat

# %%
aa.sub(9,6)
# Out:
# 3

# %%
aa.mul(45,6)
# Out:
# 270

# %% [markdown]
# ## inheritance

# %%
class parent:
    def display(self):
        print('i am parent')

# %%
class child(parent):
    def display2(self):
        print('i am child')

# %%
objaa = child()

# %%
objaa.display()
# Out:
# i am parent

# %%
objaa.display2()
# Out:
# i am child

# %%
class child2(parent):
    def display3(self):
        print('i am child2')

# %%
hello = child2()

# %%
hello.display3()
# Out:
# i am child2

# %%
class grandchild(child):
    def gdisplay(self):
        print('i am grandchild')

# %%
bye = grandchild()

# %%
bye.gdisplay()
# Out:
# i am grandchild

# %%
class parent2:
    def display2(self):
        print('i am p2')

# %%
class super(parent, parent2):
    def displaysuper(self):
        print(' i inherited all')

# %%
az = super()

# %%
az.display()
# Out:
# i am parent

# %%
az.display2()
# Out:
# i am p2

# %%
az.displaysuper()
# Out:
#  i inherited all

# %%
class A:
    def displayA(self):
        print('i am A')
class B:
    def displayB(self):
        print('i am B')
class C:
    def displayC(self):
        print('i am C')

# %%
class AA:
    def displayAA(self):
        print('i am AA')
class BB:
    def displayBB(self):
        print('i am BB')
class CC:
    def displayCC(self):
        print('i am CC')

# %%
class B(A):
    def displayBA(self):
        print('i am B')
class C(B):
    def displayCB(self):
        print('i am C')

# %%
class ABC(C,CC):
    def display(self):
        print('i am all')

# %%
kk = ABC()

# %%
class j:
    def displayj(self):
        print('j')
class k(j):
    def displayk(self):
        print('k')

# %%
class l(k,j):
    def displayl(self):
        print('l')

# %%
class calc:
    def add(self, a, b):
        print(a+b)
    def add(self,a,b,c):
        print(a+b+c)

# %%
check = calc()

# %%
check.add(2,3,6)
# Out:
# 11

# %%
class calc2:
    def __init__(self):
        self.a= 0
    def add(self, *args):
        for i in args:
            self.a+=i
        print(self.a)

# %%
jk = calc2()

# %%
jk.add(5,6,9)
# Out:
# 20

# %%
class bankaccount:
    def __init__(self,name, balance =0):
        self.name = name
        self.balance = balance
        self.transactions=[]
        self.transactions.append(f"Name:- {name}")
        self.transactions.append(f"opening balance = {balance}")
        print('welcome to our bank')
    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
        else:
            print('amount must be in positive')
            self.transactions.append(f"deposite amount is {amount} and balance is {self.balance}0")
    def withdrawl(self, amount):
        if amount< self.balance:
            self.balance = amount
        else:
            print('insufficient balance')
        self.transaction.append(f"withdrawl amount {amount} balance={self.balance}")
    def viewbalance(self):
        print(f"{self.name}, {self.balance}")
    def transaction(self):
        for i in self.transactions:
            print(i)

# %%
hitesh=bankaccount('hitesh', 500)# strong password when withdraw ask for username and password
# Out:
# welcome to our bank

# %%
hitesh.viewbalance()
# Out:
# hitesh, 500

# %%
hitesh.deposit(-580)
# Out:
# amount must be in positive

# %%
hitesh.deposit(859)

# %%
hitesh.transaction()
# Out:
# Name:- hitesh
# opening balance = 500
# deposite amount is -580 and balance is 5000

# %%
class bankaccount:
    def __init__(self, name, balance=0):
        self.name = name
        self.balance = balance
        self.transactions = []

        self.transactions.append(f"Name:- {name}")
        self.transactions.append(f"Opening balance = {balance}")
        print("Welcome to our bank")

    def authentication(self, username, password):
        special = "!@#$%^&*"

        if username != self.name:
            print("Wrong username")
            return False

        if len(password) < 8:
            print("Password must be at least 8 characters")
            return False

        if not any(c.isupper() for c in password):
            print("Password must contain a capital letter")
            return False

        if not any(c.islower() for c in password):
            print("Password must contain a small letter")
            return False

        if not any(c.isdigit() for c in password):
            print("Password must contain a digit")
            return False

        if not any(c in special for c in password):
            print("Password must contain a special character")
            return False

        print("Authentication successful")
        return True

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            self.transactions.append(
                f"Deposit {amount}, Balance {self.balance}"
            )
        else:
            print("Amount must be positive")

    def withdrawl(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            self.transactions.append(
                f"Withdraw {amount}, Balance {self.balance}"
            )
        else:
            print("Insufficient balance")

    def viewbalance(self):
        print(self.name, self.balance)

    def transaction(self):
        for i in self.transactions:
            print(i)

# %%
acc = bankaccount("Itisha", 500)
# Out:
# Welcome to our bank

# %%
acc.authentication("Itisha", "Itisha@123")
# Out:
# Authentication successful
# True

# %%
acc.authentication("Harsh", "@123")
# Out:
# Password must contain a capital letter
# False

# %%
class bankaccount:
    def __init__(self):
        self.name=input('enter name for customer')
        self.balance=int(input('enter opening balance for account'))
        self.username=input('enter username')
        while True:
            self.password = input('Enter password: ')
            pattern = r'^(?=.*[A-Z])(?=.*[a-z])(?=.*\d)(?=.*[@$!%*?&])[A-Za-z\d@$!%*?&]{8,}$'
            if re.match(pattern, self.password):
                print("Strong password accepted")
                break
            else:
                print("Weak password!")
                print("Password must contain:")
                print("- Minimum 8 characters")
                print("- 1 uppercase letter")
                print("- 1 lowercase letter")
                print("- 1 digit")
                print("- 1 special character (@$!%*?&)")
        self.transactions=[]
        self.transactions.append(f"Name:- {self.name}")
        self.transactions.append(f"opening balance= {self.balance}")
        print('welcome to our bank')
    def deposit(self):
        self.user=input('enter username')
        self.passw=input('enter password')
        if self.user==self.username and self.passw==self.password:
            self.amount=int(input('enter amount to deposit'))
            if self.amount >0:
                self.balance+=self.amount
                self.transactions.append(f"deposit amount is {self.amount} and balance is {self.balance}")
            else:
                print('amount must be in positive')
        else:
            print('wrong username')
    def withdrawl(self, amount):
        self.user=input('enter username')
        self.passw=input('enter password')
        if self.user==self.username and self.passw==self.password:
            if amount<self.balance:
                self.balance-=amount
            else:
                print('insufficient balance')
            self.transactions.append(f"withdraw amount:- {amount} balance= {self.balance}")
        else:
            print('authentication failed')
    def viewbalance(self):
        print(f"{self.name}, {self.balance}")
    def transaction(self):
        for i in self.transactions:
            print(i)

# %%
import re

# %%
acc = bankaccount()
acc.deposit()
acc.withdrawl(200)
acc.viewbalance()
acc.transaction()
# Out:
# enter name for customer Itisha
# enter opening balance for account 500
# enter username Itisha
# Enter password:  Rana@123
# Strong password accepted
# welcome to our bank
# enter username Itisha
# enter password Rana@123
# enter amount to deposit 500
# enter username Itisha
# enter password Rana@123
# authentication failed
# Itisha , 1000
# Name:- Itisha
# opening balance= 500
# deposit amount is 500 and balance is 1000
