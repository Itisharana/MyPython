# %% [markdown]
# ## File handling

# %%
file = open('cgc_winter.txt','w')

# %%
file.write('hello')
# Out:
# 5

# %%
file.close()

# %%
file = open("new_cgc_winter.txt",'w')

# %%
file.write('i am here')
# Out:
# 9

# %%
file.close()

# %%
file = open("new_cgc_winter.txt",'w')

# %%
file.write('new data')
# Out:
# 8

# %%
file.close()

# %%
file = open("new_cgc_winter.txt",'a')

# %%
file.write('\nthis is new line')
# Out:
# 17

# %%
file = open("new_cgc_winter.txt",'r')

# %%
file.read()
# Out:
# 'new data\nthis is new line'

# %%
print(read)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(read)
#
# NameError: name 'read' is not defined

# %%
file.read()

# %%
file.seek(0)

# %%
content = file.read()

# %%
print(content)

# %%
for i in file:
    print(i)

# %%
file.close()

# %%
file = open("new_cgc_winter.txt",'r')
for i in file:
    print(i.strip())
file.close()
# Out:
# new data
# this is new line

# %%
with open("new_cgc_winter.txt",'a') as f:
    for i in range(2):
        data = input()
        f.write(data+'\n')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 3
#       1 with open("new_cgc_winter.txt",'a') as f:
#       2     for i in range(2):
# ----> 3         data = input()
#       4         f.write(data+'\n')
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
# ...

# %%
with open("new_cgc_winter.txt",'a')as f:
    a = int(input('number of line'))
    for i in range(a):
        data = input()
        f.write(data+'\n')
# Out:
# number of line 5
#  i
#  am
#  itisha
#  rana
#  okay

# %%
with open("new_cgc_winter.txt",'r')as f:
    new_content = f.read()
    print(f.read())

# %%
print(new_content)
# Out:
# new data
# this is new lineking is here
# parrot files
# king is here
# parrot files
# i
# am
# itisha
# rana
# okay
# 1
# 2

# %%
with open("new_cgc_winter.txt",'r')as f:
    part = f.read(20)
    print(part)
# Out:
# new data
# this is new

# %%
count = 0
with open("new_cgc_winter.txt",'r')as f:
    for  line in f:
        count+= 1
    print("total lines" , count)
# Out:
# total lines 12

# %%
list1 = ['king', 'ring','sing']

# %%
file = open('check_file.txt','w')

# %%
file.close()

# %%
with open("check_file.txt",'w')as f:
    for ln in list1: f.write(ln+'\n')

# %%
with open("check_file.txt",'r')as f:
    part= f.read()
    print(part)
# Out:
# king
# ring
# sing

# %%
names = []

# %%
with open('check_file.txt','r') as f:
    for ln in f:
        names.append(ln.strip())

# %%
print(names)
# Out:
# ['king', 'ring', 'sing', 'king', 'ring', 'sing', 'king', 'ring', 'sing']

# %%
users = ['king', 'ring','sing']
passwords = ['123','456','789']

# %%
with open("auth.txt",'w')as f:
    for u, p in zip(users, passwords):
        f.write(f"{u},{p}\n")

# %%
users1 = []
passwords1=[]

# %%
with open('auth.txt','r') as f:
    for line in f:
        u,p = line.strip().split(",")
        users1.append(u)
        passwords1.append(p)

# %%
print(users1)
# Out:
# ['king', 'ring', 'sing']

# %%
print(passwords1)
# Out:
# ['123', '456', '789']

# %%
#use it in calculator to save data

# %%
# calculator_with_file.py

def calculate(a, b, op):
    if op == '+':
        return a + b
    elif op == '-':
        return a - b
    elif op == '*':
        return a * b
    elif op == '/':
        if b != 0:
            return a / b
        else:
            return "Error: Division by zero"
    else:
        return "Invalid operation"


# Take input
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operator = input("Enter operation (+, -, *, /): ")

# Calculate result
result = calculate(num1, num2, operator)

# Save result to file
with open("calculator_history.txt", "a") as file:
    file.write(f"{num1} {operator} {num2} = {result}\n")

print("Result:", result)

# Read history
print("\nCalculation History:")
with open("calculator_history.txt", "r") as file:
    print(file.read())
# Out:
# Enter first number:  Itisha
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 20
#      16         return "Invalid operation"
#      19 # Take input
# ---> 20 num1 = float(input("Enter first number: "))
#      21 num2 = float(input("Enter second number: "))
#      22 operator = input("Enter operation (+, -, *, /): ")
#
# ValueError: could not convert string to float: 'Itisha '

# %%
# calculator_with_file.py

def calculate(a, b, op):
    if op == '+':
        return a + b
    elif op == '-':
        return a - b
    elif op == '*':
        return a * b
    elif op == '/':
        if b != 0:
            return a / b
        else:
            return "Error: Division by zero"
    else:
        return "Invalid operation"


# Take input
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operator = input("Enter operation (+, -, *, /): ")

# Calculate result
result = calculate(num1, num2, operator)

# Save result to file
with open("calculator_history.txt", "a") as file:
    file.write(f"{num1} {operator} {num2} = {result}\n")

print("Result:", result)

# Read history
print("\nCalculation History:")
with open("calculator_history.txt", "r") as file:
    print(file.read())
# Out:
# Enter first number:  7
# Enter second number:  9
# Enter operation (+, -, *, /):  *
# Result: 63.0
#
# Calculation History:
# 67.0 8 8.0 = Invalid operation
# 8.0 * 7.0 = 56.0
# 7.0 * 9.0 = 63.0
