# %%
a=6
b=9
print(a+b)
# Out:
# 15

# %%
#can re decalre
a= 3

# %%
name = 'itisha'
b='4'

# %%
print('my name is', name)
# Out:
# my name is itisha

# %%
print('2'+ name)
# Out:
# 2itisha

# %%
print(b+ name)
# Out:
# 4itisha

# %%
print(str(a)+ name)
# Out:
# 3itisha

# %%
type(name)
# Out:
# str

# %%
type(a)
# Out:
# int

# %%
print (a+ int(b))
# Out:
# 7

# %%
type(b)
# Out:
# str

# %%
b = int(b)

# %%
type(b)
# Out:
# int

# %%
b
# Out:
# 4

# %%
z= input()
y = input()
print(z+y)
# Out:
#  itisha
#  rana
# itisha rana

# %%
cities =  '''landran
mohali
jaunpur'''

# %%
print(cities)
# Out:
# landran
# mohali
# jaunpur

# %%
cities =  'landran\n mohali\n jaunpur'

# %%
print(cities)
# Out:
# landran
#  mohali
#  jaunpur

# %%
new_cities = r'this\is\raw\data\string'

# %%
print(new_cities)
# Out:
# this\is\raw\data\string

# %%
#JrGraphics.net

value = '\u0927\u0928'

# %%
print(value)
# Out:
# धन

# %%
values ='\u0915\u0928\u093f\u0937\u094d\u0915\u093e \u0938\u093f\u0902\u0939'

# %%
print(values)
# Out:
# कनिष्का सिंह

# %%
value = '\u0907\u0924\u093f\u0936\u093e \u0930\u093e\u0923\u093e \u091c\u0940'
print(value)
# Out:
# इतिशा राणा जी
