# %%
list1 = []

# %%
type(list1)
# Out:
# list

# %%
list2 = ['king',  'djd', 2, 3]

# %%
list2
# Out:
# ['king', 'djd', 2, 3]

# %% [markdown]
# ## modifying list
# 1. index
# 2. count
# 3. sort
# 4. append
# 5. remove
# 6. pop
# 7. extend
# 8. insert

# %%
print(list2[1])
# Out:
# djd

# %% [markdown]
# ## slicing

# %%
print(list2[1:3])
# Out:
# ['djd', 2]

# %%
print(list2[:-1])
# Out:
# ['king', 'djd', 2]

# %%
print(list2[-1:])
# Out:
# [3]

# %%
print(list2[-3])
# Out:
# djd

# %%
list2[1] = 'queen'

# %%
list2
# Out:
# ['king', 'queen', 2, 3]

# %% [markdown]
# ## indexing

# %%
list2.index('queen')
# Out:
# 1

# %%
list3 =['king',  'djd', 2,'king',  'queen', ]

# %%
list3.index('king')
# Out:
# 0

# %%
list3.index('king', 1)
# Out:
# 3

# %%
list3.index('king', 1, 4)
# Out:
# 3

# %%
list3.index('king', 1, 3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 list3.index('king', 1, 3)
#
# ValueError: 'king' is not in list

# %% [markdown]
# ### count

# %%
list3.count('king')
# Out:
# 2

# %% [markdown]
# ### sort

# %%
list4 = [215,655,32,85,12,21]

# %%
list4
# Out:
# [12, 21, 32, 85, 215, 655]

# %%
list4.sort()

# %%
print(list4.sort())
# Out:
# None

# %%
print(sorted(list4))
# Out:
# [12, 21, 32, 85, 215, 655]

# %%
list5 = sorted(list4)

# %%
list5
# Out:
# [5, 12, 21, 32, 85, 215, 655]

# %%
list5.sort(reverse= True)

# %%
list5
# Out:
# [655, 215, 85, 32, 21, 12, 5]

# %% [markdown]
# ## append

# %%
list4.append(5)

# %%
list4
# Out:
# [12, 21, 32, 85, 215, 655, 5]

# %% [markdown]
# ## remove

# %%
list4.remove(215)

# %%
list4
# Out:
# [12, 21, 32, 85, 655, 5]

# %% [markdown]
# ## pop

# %%
list3
# Out:
# ['king', 'djd', 2, 'king', 'queen']

# %%
list3.pop(3)
# Out:
# 'king'

# %%
list3
# Out:
# ['king', 'djd', 2, 'queen']

# %% [markdown]
# ## extend

# %%
list3.extend([5,9,3])

# %%
list3
# Out:
# ['king', 'djd', 2, 'queen', 5, 9, 3]

# %% [markdown]
# ## insert

# %%
list3.insert(1,5)

# %%
list3
# Out:
# ['king', 5, 'djd', 2, 'queen', 5, 9, 3]

# %%
list3.insert(1,'is')

# %%
list3
# Out:
# ['king', 'is', 5, 'djd', 2, 'queen', 5, 9, 3]

# %% [markdown]
# ## list  insertion

# %%
list3.insert(2,list4)

# %%
list3
# Out:
# ['king', 'is', [12, 21, 32, 85, 655, 5], 5, 'djd', 2, 'queen', 5, 9, 3]

# %%
print(list3[2][0])
# Out:
# 12

# %%
print(list3[2])
# Out:
# [12, 21, 32, 85, 655, 5]

# %%
print(list3[2][1:3])
# Out:
# [21, 32]

# %%
list3[2].append('added')

# %%
print(list3)
# Out:
# ['king', 'is', [12, 21, 32, 85, 655, 5, 'added'], 5, 'djd', 2, 'queen', 5, 9, 3]

# %%
name= 'itisha'

# %%
list3[2].append(name)

# %%
list3[2]
# Out:
# [12, 21, 32, 85, 655, 5, 'added', 'itisha']

# %%
harsh = [546,54,5,'jdvbi','hcb']

# %%
harsh.insert(2,[654,'hndhb',4,699])

# %%
harsh
# Out:
# [546, 54, [654, 'hndhb', 4, 699], 5, 'jdvbi', 'hcb']

# %%
harsh[2].remove('hndhb')

# %%
harsh
# Out:
# [546, 54, [654, 4, 699], 5, 'jdvbi', 'hcb']

# %%
harsh[2].pop(1)
# Out:
# 4

# %% [markdown]
# ## tuples

# %%
tup = ('j', 'djehdw', 'edjhweuf','j')

# %%
type(tup)
# Out:
# tuple

# %%
tup[2]
# Out:
# 'edjhweuf'

# %%
tup.count('j')
# Out:
# 2

# %%
tup.count('jn')
# Out:
# 0

# %%
tup.index('j', 1)
# Out:
# 3

# %%
new= list(tup)

# %%
new
# Out:
# ['j', 'djehdw', 'edjhweuf', 'j']

# %%
type(tup)
# Out:
# tuple

# %%
type(new)
# Out:
# list

# %%
new = tuple(new)

# %%
new
# Out:
# ('j', 'djehdw', 'edjhweuf', 'j')

# %%
type(new)
# Out:
# tuple

# %% [markdown]
# ## dictionary

# %%
student = {'name':'itisha', 'age':21}

# %%
student
# Out:
# {'name': 'itisha', 'age': 21}

# %%
student['name']
# Out:
# 'itisha'

# %%
student['name'] = 'rana'

# %%
student['name']
# Out:
# 'rana'

# %%
student['number'] = 65482

# %%
student
# Out:
# {'name': 'rana', 'age': 21, 'number': 65482}

# %%
student['address' ] ='mandi'

# %%
student
# Out:
# {'name': 'rana', 'age': 21, 'number': 65482, 'address': 'mandi'}

# %%
student.update({'name' :'itisha', 'rollno' : 2236823})

# %%
student
# Out:
# {'name': 'itisha',
#  'age': 21,
#  'number': 65482,
#  'address': 'mandi',
#  'rollno': 2236823}

# %%
student.pop('address')
# Out:
# 'mandi'

# %%
student
# Out:
# {'name': 'itisha', 'age': 21, 'number': 65482, 'rollno': 2236823}

# %%
del student['number']

# %%
student
# Out:
# {'name': 'itisha', 'age': 21, 'rollno': 2236823}

# %%
print(student.get('number', 'not found'))
# Out:
# not found

# %%
print(student.get('name', 'not found'))
# Out:
# itisha

# %% [markdown]
# ## nested dictionary

# %%
students ={ 
    'student1':{
        'name':'kamla',
        'roll bo': 1},
    'student2':{
        'name':'kom',
        'roll bo': 2}
}

# %%
students
# Out:
# {'student1': {'name': 'kamla', 'roll bo': 1},
#  'student2': {'name': 'kom', 'roll bo': 2}}

# %%
print(students['student1']['name'])
# Out:
# kamla

# %%
students['student1']['name']
# Out:
# 'kamla'

# %%
len(students)
# Out:
# 2

# %%
len(students['student1'])
# Out:
# 2

# %%
students.values()
# Out:
# dict_values([{'name': 'kamla', 'roll bo': 1}, {'name': 'kom', 'roll bo': 2}])

# %%
students.keys()
# Out:
# dict_keys(['student1', 'student2'])

# %%
students.items()
# Out:
# dict_items([('student1', {'name': 'kamla', 'roll bo': 1}), ('student2', {'name': 'kom', 'roll bo': 2})])

# %%
'student1' in students
# Out:
# True

# %%
'student4' in students
# Out:
# False

# %%
'kamla'in students['student1'].values()
# Out:
# True

# %%
'name'in students['student1'].keys()
# Out:
# True

# %%
 'kamla'in students['student1'].keys()
# Out:
# False

# %% [markdown]
# ## sets

# %%
 set1= {'king', 'queen', 'horse'}

# %%
set1
# Out:
# {'horse', 'king', 'queen'}

# %%
set1.pop()
# Out:
# 'horse'

# %%
set1.update({'king'})

# %%
set1
# Out:
# {'king', 'queen'}

# %%
set1.remove('queen')

# %%
set1
# Out:
# {'king'}

# %%
lists= list(set1)

# %%
type(lists)
# Out:
# list

# %%
type(set1)
# Out:
# set

# %%
lists
# Out:
# ['king']

# %%
set1.update({'queen', 'elephant'})

# %%
set1
# Out:
# {'elephant', 'king', 'queen'}

# %%
set1.update({'elephant'})

# %%
set1
# Out:
# {'elephant', 'king', 'queen'}

# %% [markdown]
# ## string methods

# %%
name2 ='queen'

# %%
print(name2.upper())
# Out:
# QUEEN

# %%
name3 = input().lower()
print(name3)
# Out:
#  ITISHA
# itisha

# %%
name4='itisha'

# %%
print(name4.capitalize())
# Out:
# Itisha

# %%
sentence = '  djcuywg jhfgewy'

# %%
sentence.strip()
# Out:
# 'djcuywg jhfgewy'

# %%
sentence.split()
# Out:
# ['djcuywg', 'jhfgewy']

# %%
sentence.count('g')
# Out:
# 2

# %%
sentence1 =['jndnj', 'dju' , 'cdhbc']

# %%
print(' '.join(sentence1))
# Out:
# jndnj dju cdhbc

# %%
sentence2 ='jiefgewufygfhewgfewygf'

# %%
sentence2.isalpha()
# Out:
# True

# %%
sentence2.isdigit()
# Out:
# False
